# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
import joblib

# %%
modelo = joblib.load('ModelRS.joblib')

# %%
# Data
data = {  
    'MaxTemp': [20.3], 
    'MinTemp': [10.1],
    'Rainfall': [0.2],
    'Evaporation': [4.3],
    'Sunshine': [8.2],
    'WindGustDir': ['N'],  
    'WindGustSpeed': [30],
    'WindDir9am': ['N'], 
    'WindDir3pm': ['S'],  
    'WindSpeed9am': [15],
    'WindSpeed3pm': [20],
    'Humidity9am': [60],
    'Humidity3pm': [40],
    'Pressure9am': [1015],
    'Pressure3pm': [1010],
    'Cloud9am': [2],
    'Cloud3pm': [3],
    'Temp9am': [15],
    'Temp3pm': [18],
    'RainToday': ['No'],
    'RainfallTomorrow': [0]
}
df = pd.DataFrame(data)

# %%
file_path= 'weatherAUS.csv'
weather_data = pd.read_csv(file_path, sep=',',engine='python')

# %%
# Cargamos el dataset original y fiteamos el transform
# Crear el estandarizador
scaler = StandardScaler()

# %%
columns_to_standardize = ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
                        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
                        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
                        'Temp3pm', 'RainfallTomorrow']

# %%
# Aplicar la estandarización a las columnas seleccionadas
weather_data[columns_to_standardize] = scaler.fit_transform(weather_data[columns_to_standardize])

# %%
# Selecciona la primera fila de 'df'
fila_a_agregar = df.iloc[0]  

# Agrega la fila a 'weather_date'
weather_data.loc[len(weather_data)] = fila_a_agregar

# Elimina las columnas inecesarias
weather_data = weather_data.drop(['Unnamed: 0', 'Date', 'Location'], axis=1)

# %%
weather_data
# Out:
#           MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        0.188204  -0.045398 -0.207743          NaN       NaN           W
# 1       -0.749590   0.263645 -0.278503          NaN       NaN         WNW
# 2        0.110054   0.347930 -0.278503          NaN       NaN         WSW
# 3       -0.468252   0.671020 -0.278503          NaN       NaN          NE
# 4        0.829029   1.275059 -0.160569          NaN       NaN           W
# ...           ...        ...       ...          ...       ...         ...
# 145408  -1.468565   0.024839 -0.278503          NaN       NaN           E
# 145409  -1.343526   0.291740 -0.278503          NaN       NaN         NNW
# 145410  -1.062188   0.516499 -0.278503          NaN       NaN           N
# 145411  -0.687070   0.530546 -0.278503          NaN       NaN          SE
# 145412  10.100000  20.300000  0.200000          4.3       8.2           N
#
#         WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0            0.291276          W        WNW      0.667961  ...    -1.420298
# 1            0.291276        NNW        WSW     -1.126651  ...    -1.276044
# 2            0.438257          W        WSW      0.555798  ...    -1.035620
# 3           -1.178539         SE          E     -0.341508  ...    -1.708806
# 4            0.070804        ENE         NW     -0.790161  ...    -0.891366
# ...               ...        ...        ...           ...  ...          ...
# 145408      -0.664104         SE        ENE     -0.117182  ...    -1.324129
# 145409      -1.325520         SE          N     -0.117182  ...    -1.468383
# 145410      -0.223159         SE        WNW     -0.565834  ...    -1.324129
# 145411      -0.884576        SSE          N     -0.117182  ...    -1.324129
# 145412      30.000000          N          S     15.000000  ...    40.000000
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm    Temp9am    Temp3pm  \
# 0         -1.399906    -1.158744  1.230528       NaN  -0.014300   0.016543
# 1         -0.991863    -1.059283       NaN       NaN   0.031939   0.376964
# 2         -1.413976    -0.931405       NaN -0.922611   0.617634   0.218379
# 3         -0.006933    -0.348849       NaN       NaN   0.170656   0.694135
# 4         -0.963723    -1.315039  0.884165  1.283036   0.124417   1.155474
# ...             ...          ...       ...       ...        ...        ...
# 145408     0.977996     0.716802       NaN       NaN  -1.062385   0.103044
# 145409     0.823222     0.546297       NaN       NaN  -0.939081   0.405798
# 145410     0.471461     0.219498       NaN       NaN  -0.692473   0.636467
# 145411     0.246334     0.176872 -0.501287 -0.922611  -0.291735   0.622051
# 145412  1015.000000  1010.000000  2.000000  3.000000  15.000000  18.000000
#
#         RainToday  RainTomorrow RainfallTomorrow
# 0              No            No        -0.278479
# 1              No            No        -0.278479
# 2              No            No        -0.278479
# 3              No            No        -0.160542
# 4              No            No        -0.254892
# ...           ...           ...              ...
# 145408         No            No        -0.278479
# 145409         No            No        -0.278479
# 145410         No            No        -0.278479
# 145411         No            No        -0.278479
# 145412         No           NaN         0.000000
#
# [145413 rows x 22 columns]

# %%
diccionario = {
            'N': ['N', 'NNW', 'NNE', 'NE', 'NW'],
            'S': ['S', 'SSW', 'SSE', 'SE', 'SW'],
            'E': ['E', 'ENE', 'ESE'],
            'W': ['W', 'WNW', 'WSW'],
        }

# %%
# Invertir el diccionario para el mapeo
diccionario_invertido = {valor: clave for clave, lista_valores in diccionario.items() for valor in lista_valores}

# Aplicar la transformación a WindGustDir
weather_data['WindGustDir'] = weather_data['WindGustDir'].map(diccionario_invertido)

# Aplicar la transformación a WindDir9am
weather_data['WindDir9am'] = weather_data['WindDir9am'].map(diccionario_invertido)

# Aplicar la transformación a WindDir3pm
weather_data['WindDir3pm'] = weather_data['WindDir3pm'].map(diccionario_invertido)

columns_to_dummy = ['WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']
weather_data_dummies = pd.get_dummies(weather_data, columns=columns_to_dummy, drop_first=True)
weather_data_dummies.replace({True: 1, False: 0}, inplace=True)
# Out:
# C:\Users\src4\AppData\Local\Temp\ipykernel_21624\1514932736.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_data_dummies.replace({True: 1, False: 0}, inplace=True)

# %%
weather_data_dummies
# Out:
#           MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0        0.188204  -0.045398 -0.207743          NaN       NaN       0.291276
# 1       -0.749590   0.263645 -0.278503          NaN       NaN       0.291276
# 2        0.110054   0.347930 -0.278503          NaN       NaN       0.438257
# 3       -0.468252   0.671020 -0.278503          NaN       NaN      -1.178539
# 4        0.829029   1.275059 -0.160569          NaN       NaN       0.070804
# ...           ...        ...       ...          ...       ...            ...
# 145408  -1.468565   0.024839 -0.278503          NaN       NaN      -0.664104
# 145409  -1.343526   0.291740 -0.278503          NaN       NaN      -1.325520
# 145410  -1.062188   0.516499 -0.278503          NaN       NaN      -0.223159
# 145411  -0.687070   0.530546 -0.278503          NaN       NaN      -0.884576
# 145412  10.100000  20.300000  0.200000          4.3       8.2      30.000000
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 0           0.667961      0.605753     0.111548    -1.420298  ...
# 1          -1.126651      0.378745    -1.307301    -1.276044  ...
# 2           0.555798      0.832762    -1.622600    -1.035620  ...
# 3          -0.341508     -1.096810    -1.254751    -1.708806  ...
# 4          -0.790161      0.151737     0.689598    -0.891366  ...
# ...              ...           ...          ...          ...  ...
# 145408     -0.117182     -0.869801    -0.939451    -1.324129  ...
# 145409     -0.117182     -1.096810    -0.676701    -1.468383  ...
# 145410     -0.565834     -1.096810    -0.834351    -1.324129  ...
# 145411     -0.117182     -1.323818    -0.939451    -1.324129  ...
# 145412     15.000000     20.000000    60.000000    40.000000  ...
#
#         WindGustDir_S  WindGustDir_W  WindDir9am_N  WindDir9am_S  \
# 0                   0              1             0             0
# 1                   0              1             1             0
# 2                   0              1             0             0
# 3                   0              0             0             1
# 4                   0              1             0             0
# ...               ...            ...           ...           ...
# 145408              0              0             0             1
# 145409              0              0             0             1
# 145410              0              0             0             1
# 145411              1              0             0             1
# 145412              0              0             1             0
#
#         WindDir9am_W  WindDir3pm_N  WindDir3pm_S  WindDir3pm_W  RainToday_Yes  \
# 0                  1             0             0             1              0
# 1                  0             0             0             1              0
# 2                  1             0             0             1              0
# 3                  0             0             0             0              0
# 4                  0             1             0             0              0
# ...              ...           ...           ...           ...            ...
# 145408             0             0             0             0              0
# 145409             0             1             0             0              0
# 145410             0             0             0             1              0
# 145411             0             1             0             0              0
# 145412             0             0             1             0              0
#
#         RainTomorrow_Yes
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 145408                 0
# 145409                 0
# 145410                 0
# 145411                 0
# 145412                 0
#
# [145413 rows x 28 columns]

# %%
last_row = weather_data_dummies.tail(1)
last_row
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 145412     10.1     20.3       0.2          4.3       8.2           30.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 145412          15.0          20.0         60.0         40.0  ...
#
#         WindGustDir_S  WindGustDir_W  WindDir9am_N  WindDir9am_S  \
# 145412              0              0             1             0
#
#         WindDir9am_W  WindDir3pm_N  WindDir3pm_S  WindDir3pm_W  RainToday_Yes  \
# 145412             0             0             1             0              0
#
#         RainTomorrow_Yes
# 145412                 0
#
# [1 rows x 28 columns]

# %%
# Aplicar la estandarización a las columnas seleccionadas
last_row[columns_to_standardize] = scaler.transform(last_row[columns_to_standardize])
# Out:
# C:\Users\src4\AppData\Local\Temp\ipykernel_21624\2667120450.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row[columns_to_standardize] = scaler.transform(last_row[columns_to_standardize])

# %%
df
# Out:
#     MaxTemp   MinTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0 -0.410631 -0.327583 -0.254917     -0.27865  0.155526           N
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0      -0.737594          N          S      0.107145  ...    -0.466501
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm   Temp9am  \
# 0    -0.554774    -0.372765    -0.746692  -0.84765 -0.555003 -0.307148
#
#     Temp3pm  RainToday RainfallTomorrow
# 0 -0.531296         No        -0.278479
#
# [1 rows x 21 columns]

# %%
# Drop unnecessary columns
df = df.drop('RainfallTomorrow', axis=1)

# %%
df
# Out:
#     MaxTemp   MinTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0 -0.410631 -0.327583 -0.254917     -0.27865  0.155526           N
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0      -0.737594          N          S      0.107145      0.151737
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0    -0.466501    -0.554774    -0.372765    -0.746692  -0.84765 -0.555003
#
#     Temp9am   Temp3pm RainToday
# 0 -0.307148 -0.531296        No

# %%
columns_to_dummy = ['WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday']
df_prosseced = pd.get_dummies(df, columns=columns_to_dummy)

# %%
df_prosseced
# Out:
#     MaxTemp   MinTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0 -0.410631 -0.327583 -0.254917     -0.27865  0.155526      -0.737594
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0      0.107145      0.151737    -0.466501    -0.554774    -0.372765
#
#    Pressure3pm  Cloud9am  Cloud3pm   Temp9am   Temp3pm  WindGustDir_N  \
# 0    -0.746692  -0.84765 -0.555003 -0.307148 -0.531296           True
#
#    WindDir9am_N  WindDir3pm_S  RainToday_No
# 0          True          True          True

# %%
df_prosseced.replace({True: 1, False: 0}, inplace=True)
# Out:
# C:\Users\src4\AppData\Local\Temp\ipykernel_25116\2738033763.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_prosseced.replace({True: 1, False: 0}, inplace=True)

# %%
df_prosseced
# Out:
#     MaxTemp   MinTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0 -0.410631 -0.327583 -0.254917     -0.27865  0.155526      -0.737594
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0      0.107145      0.151737    -0.466501    -0.554774    -0.372765
#
#    Pressure3pm  Cloud9am  Cloud3pm   Temp9am   Temp3pm  WindGustDir_N  \
# 0    -0.746692  -0.84765 -0.555003 -0.307148 -0.531296              1
#
#    WindDir9am_N  WindDir3pm_S  RainToday_No
# 0             1             1             1

# %%
df_prosseced
# Out:
#     MaxTemp   MinTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0 -0.410631 -0.327583 -0.254917     -0.27865  0.155526      -0.737594
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0      0.107145      0.151737    -0.466501    -0.554774    -0.372765
#
#    Pressure3pm  Cloud9am  Cloud3pm   Temp9am   Temp3pm  WindGustDir_N  \
# 0    -0.746692  -0.84765 -0.555003 -0.307148 -0.531296              1
#
#    WindDir9am_N  WindDir3pm_S  RainToday_No
# 0             1             1             1

# %%
prediccion = modelo.predict(df_prosseced)
prediccion
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 prediccion = modelo.predict(df_prosseced)
#       2 prediccion
#
# File c:\Users\src4\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:547, in BaseSearchCV.predict(self, X)
#     529 """Call predict on the estimator with the best found parameters.
#     530
#     531 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     544     the best found parameters.
#     545 """
#     546 check_is_fitted(self)
# --> 547 return self.best_estimator_.predict(X)
#
# File c:\Users\src4\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:382, in LinearClassifierMixin.predict(self, X)
#     368 """
#     369 Predict class labels for samples in X.
#     370
#    (...)
#     379     Vector containing the class labels for each sample.
#     380 """
#     381 xp, _ = get_namespace(X)
# --> 382 scores = self.decision_function(X)
#     383 if len(scores.shape) == 1:
#     384     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File c:\Users\src4\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:363, in LinearClassifierMixin.decision_function(self, X)
#     360 check_is_fitted(self)
#     361 xp, _ = get_namespace(X)
# --> 363 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     364 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     365 return xp.reshape(scores, (-1,)) if scores.shape[1] == 1 else scores
#
# File c:\Users\src4\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File c:\Users\src4\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - RainToday_No
# Feature names seen at fit time, yet now missing:
# - RainToday_Yes
# - WindDir3pm_N
# - WindDir3pm_W
# - WindDir9am_S
# - WindDir9am_W
# - ...
